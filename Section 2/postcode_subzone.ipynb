# %%
import pandas as pd
import numpy as np

import requests
import time
from typing import Dict, List, Optional
from shaply.geometry import Point, Polygon, shape

import geopandas as gpd
from bs4 import BeautifulSoup

# %% [markdown]
# # get lat, lon

# %%
def lookup_postcode_details(postcode: str) -> Dict:

    # OneMap Search API endpoint
    api_url = "https://www.onemap.gov.sg/api/common/elastic/search"

    # API
    params = {
        'searchVal': postcode,
        'returnGeom': 'Y',
        'getAddrDetails': 'Y',
        'pageNum': 1
    }
    headers = {"Authorization": "Bearer **********************"}

    try:
        # request
        response = requests.get(api_url, params=params, headers=headers, timeout=10)
        response.raise_for_status()
        
        data = response.json()
        
        if data['found'] > 0:
            result = data['results'][0]
            
            return {
                'latitude': float(result.get('LATITUDE', 0)),
                'longitude': float(result.get('LONGITUDE', 0)),
            }
        else:
            return {
                'postcode': postcode,
                'status': 'not_found'
            }
            
    except requests.exceptions.RequestException as e:
        return {
            'postcode': postcode,
            'status': 'error',
            'error': str(e)
        }



def batch_lookup_postcodes(postcodes: List[str], token: Optional[str] = None, delay: float = 0.1) -> pd.DataFrame:
    
    results = []
    total = len(postcodes)
    
    for i, postcode in enumerate(postcodes):
        # clean
        clean_postcode = str(postcode).strip().zfill(6)
        
        # query
        result = lookup_postcode_details(clean_postcode)
        results.append(result)
        
        # progress bar
        if (i + 1) % 10 == 0 or (i + 1) == total:
            print(f"Done: {i + 1}/{total}")
        
        # delay 
        if delay > 0 and i < total - 1:
            time.sleep(delay)
    
    df = pd.DataFrame(results)

    return df

# %%
# save result
df_childcare = pd.read_csv('./data/3_ListingofCentres.csv')

# get unique post codes
df_childcare = df_childcare[df_childcare['postal_code'] > 0]
ls_postal = df_childcare['postal_code'].astype(int).unique().tolist()  #1813 unique value

# run batch lookup
df = batch_lookup_postcodes(ls_postal)

# %%
# save result
df['postcode'] = ls_postal
df.to_csv('./data_processed/postcode_ll.csv', index=False)

# %% [markdown]
# # map to subzone

# %%
# Load the subzone boundaries shapefile
subzone_gdf = gpd.read_file('./data/MasterPlan2019SubzoneBoundaryNoSea/Master Plan 2019 Subzone Boundary (No Sea) (GEOJSON).geojson')

# %%
def getName(html):
    soup = BeautifulSoup(html, 'html.parser')

    #  <th>SUBZONE_N</th> follow <td>。
    th = soup.find('th', string='SUBZONE_N')
    if th:
        td = th.find_next_sibling('td')
        subzone_name = td.get_text(strip=True) if td else None
    else:
        subzone_name = None

    print("Subzone:", subzone_name)
    return subzone_name

def getSubzone(x):
    if np.isnan(x.longitude):
        return ''
        
    point = Point(x.longitude, x.latitude)  
    
    mask = subzone_gdf.geometry.contains(point)
    matching_rows = subzone_gdf[mask]
    
    html = matching_rows['Description'].values[0]
    return getName(html)

# %%
df['Subzone'] = df.apply(lambda x: getSubzone(x), axis=1)
# Out:
# Subzone: ULU PANDAN
# Subzone: GOMBAK
# Subzone: HONG KAH NORTH
# Subzone: TOH TUCK
# Subzone: UPPER PAYA LEBAR
# Subzone: ROBERTSON QUAY
# Subzone: BUKIT BATOK CENTRAL
# Subzone: SIMEI
# Subzone: BIDADARI
# Subzone: HONG KAH
# Subzone: UPPER THOMSON
# Subzone: BOON LAY PLACE
# Subzone: SELETAR HILLS
# Subzone: XILIN
# Subzone: FERNVALE
# Subzone: LORONG AH SOO
# Subzone: FERNVALE
# Subzone: KATONG
# Subzone: HOUGANG CENTRAL
# Subzone: HILLVIEW
# Subzone: GEYLANG EAST
# Subzone: WOODLANDS EAST
# Subzone: WENYA
# Subzone: YIO CHU KANG EAST
# Subzone: KOVAN
# Subzone: WENYA
# Subzone: GARDEN
# Subzone: BEDOK SOUTH
# Subzone: PLANTATION
# Subzone: MATILDA
# Subzone: CLEMENTI NORTH
# Subzone: HONG KAH
# Subzone: TIONG BAHRU STATION
# Subzone: MACPHERSON
# Subzone: HONG KAH
# Subzone: TEBAN GARDENS
# Subzone: BUKIT BATOK CENTRAL
# Subzone: HILLVIEW
# Subzone: FERNVALE
# Subzone: TAMPINES EAST
# Subzone: TAMPINES EAST
# Subzone: TRAFALGAR
# Subzone: CECIL
# Subzone: SEMBAWANG NORTH
# Subzone: SEMBAWANG NORTH
# Subzone: TOH TUCK
# Subzone: YISHUN SOUTH
# Subzone: KEMBANGAN
# Subzone: KAMPONG UBI
# Subzone: HONG KAH NORTH
# Subzone: KEMBANGAN
# Subzone: HONG KAH
# Subzone: HONG KAH
# Subzone: YUHUA WEST
# Subzone: HONG KAH
# Subzone: CECIL
# Subzone: LORONG 8 TOA PAYOH
# Subzone: FRANKEL
# Subzone: GEYLANG EAST
# Subzone: GEYLANG EAST
# Subzone: PASIR PANJANG 2
# Subzone: TAMPINES EAST
# Subzone: TAMPINES EAST
# Subzone: FERNVALE
# Subzone: FERNVALE
# Subzone: FERNVALE
# Subzone: CORONATION ROAD
# Subzone: FERNVALE
# Subzone: FERNVALE
# Subzone: FERNVALE
# Subzone: MIDVIEW
# Subzone: MIDVIEW
# Subzone: MIDVIEW
# Subzone: KEBUN BAHRU
# Subzone: KEBUN BAHRU
# Subzone: NEWTON CIRCUS
# Subzone: DEPOT ROAD
# Subzone: KENT RIDGE
# Subzone: MARITIME SQUARE
# Subzone: BOULEVARD
# Subzone: CLEMENTI WOODS
# Subzone: TELOK BLANGAH RISE
# Subzone: KAMPONG JAVA
# Subzone: KAMPONG JAVA
# Subzone: CRAWFORD
# Subzone: TOH GUAN
# Subzone: SENGKANG TOWN CENTRE
# Subzone: ANCHORVALE
# Subzone: TAMPINES WEST
# Subzone: YISHUN WEST
# Subzone: TOWNSVILLE
# Subzone: TAMPINES EAST
# Subzone: TIONG BAHRU
# Subzone: ANAK BUKIT
# Subzone: TEBAN GARDENS
# Subzone: WOODLANDS SOUTH
# Subzone: RIVERVALE
# Subzone: WOODLANDS SOUTH
# Subzone: BEDOK NORTH
# Subzone: SEMBAWANG CENTRAL
# Subzone: WOODLANDS EAST
# Subzone: YIO CHU KANG EAST
# Subzone: CORONATION ROAD
# Subzone: SERANGOON GARDEN
# Subzone: FRANKEL
# Subzone: CLARKE QUAY
# Subzone: TAMAN JURONG
# Subzone: ALEXANDRA HILL
# Subzone: SEMBAWANG CENTRAL
# Subzone: KAMPONG UBI
# Subzone: TAMPINES EAST
# Subzone: YIO CHU KANG
# Subzone: ALJUNIED
# Subzone: FERNVALE
# Subzone: WOODLANDS SOUTH
# Subzone: CENTRAL SUBZONE
# Subzone: SERANGOON NORTH
# Subzone: SAUJANA
# Subzone: TAMPINES EAST
# Subzone: LORONG AH SOO
# Subzone: MARITIME SQUARE
# Subzone: NORTHLAND
# Subzone: ORANGE GROVE
# Subzone: YISHUN SOUTH
# Subzone: JURONG WEST CENTRAL
# Subzone: NATURE RESERVE
# Subzone: UPPER PAYA LEBAR
# Subzone: HONG KAH NORTH
# Subzone: SHANGRI-LA
# Subzone: LEEDON PARK
# Subzone: BEDOK NORTH
# Subzone: PASIR PANJANG 1
# Subzone: JOO SENG
# Subzone: BEDOK NORTH
# Subzone: BEDOK RESERVOIR
# Subzone: PASIR RIS DRIVE
# Subzone: TAMPINES EAST
# Subzone: PASIR RIS CENTRAL
# Subzone: YUNNAN
# Subzone: YUNNAN
# Subzone: SEMBAWANG CENTRAL
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: KAKI BUKIT
# Subzone: SWISS CLUB
# Subzone: CLEMENTI WEST
# Subzone: HOUGANG WEST
# Subzone: TAMPINES EAST
# Subzone: PASIR PANJANG 2
# Subzone: BALESTIER
# Subzone: MOUNTBATTEN
# Subzone: FRANKEL
# Subzone: PASIR RIS DRIVE
# Subzone: YISHUN EAST
# Subzone: RIVERVALE
# Subzone: FRANKEL
# Subzone: TAMPINES EAST
# Subzone: TAMPINES WEST
# Subzone: MARYMOUNT
# Subzone: DUNEARN
# Subzone: LORONG AH SOO
# Subzone: KOVAN
# Subzone: RIVERVALE
# Subzone: SAUJANA
# Subzone: KAKI BUKIT
# Subzone: CHATSWORTH
# Subzone: MARINA CENTRE
# Subzone: SERANGOON NORTH IND ESTATE
# Subzone: MOULMEIN
# Subzone: LORONG AH SOO
# Subzone: HONG KAH
# Subzone: BUKIT BATOK WEST
# Subzone: CHOA CHU KANG NORTH
# Subzone: KAKI BUKIT
# Subzone: YISHUN CENTRAL
# Subzone: TAMAN JURONG
# Subzone: WOODGROVE
# Subzone: TAMPINES EAST
# Subzone: XILIN
# Subzone: SIMEI
# Subzone: PASIR RIS DRIVE
# Subzone: BUKIT BATOK EAST
# Subzone: BEDOK RESERVOIR
# Subzone: LORONG AH SOO
# Subzone: TAMPINES EAST
# Subzone: PUNGGOL FIELD
# Subzone: CHENG SAN
# Subzone: GARDEN
# Subzone: KALLANG BAHRU
# Subzone: OXLEY
# Subzone: MARGARET DRIVE
# Subzone: CHATSWORTH
# Subzone: OXLEY
# Subzone: BEDOK NORTH
# Subzone: YISHUN CENTRAL
# Subzone: TAMPINES NORTH
# Subzone: MARYMOUNT
# Subzone: BEDOK RESERVOIR
# Subzone: PASIR RIS WEST
# Subzone: TAMPINES WEST
# Subzone: RIVERVALE
# Subzone: BEDOK NORTH
# Subzone: BRICKWORKS
# Subzone: YISHUN EAST
# Subzone: ALJUNIED
# Subzone: PASIR PANJANG 2
# Subzone: LORONG CHUAN
# Subzone: INTERNATIONAL BUSINESS PARK
# Subzone: BUKIT BATOK SOUTH
# Subzone: SEMBAWANG CENTRAL
# Subzone: TOH GUAN
# Subzone: BOON LAY PLACE
# Subzone: CORONATION ROAD
# Subzone: CHOA CHU KANG NORTH
# Subzone: NORTHSHORE
# Subzone: PASIR RIS CENTRAL
# Subzone: JOO SENG
# Subzone: SENGKANG TOWN CENTRE
# Subzone: BEDOK SOUTH
# Subzone: BEDOK NORTH
# Subzone: SIMEI
# Subzone: BUKIT BATOK CENTRAL
# Subzone: KEMBANGAN
# Subzone: CRAWFORD
# Subzone: SERANGOON CENTRAL
# Subzone: ANAK BUKIT
# Subzone: WOODLANDS EAST
# Subzone: NORTHLAND
# Subzone: MIDVIEW
# Subzone: LITTLE INDIA
# Subzone: YUNNAN
# Subzone: GOMBAK
# Subzone: TOH GUAN
# Subzone: REDHILL
# Subzone: MARYMOUNT
# Subzone: TAMAN JURONG
# Subzone: RIVERVALE
# Subzone: TAMPINES EAST
# Subzone: TAMPINES WEST
# Subzone: TELOK BLANGAH DRIVE
# Subzone: WEST COAST
# Subzone: YISHUN EAST
# Subzone: CLEMENTI WOODS
# Subzone: WOODLANDS EAST
# Subzone: YISHUN EAST
# Subzone: GARDEN
# Subzone: SEMBAWANG CENTRAL
# Subzone: SENGKANG TOWN CENTRE
# Subzone: TAMPINES EAST
# Subzone: TAMPINES WEST
# Subzone: FRANKEL
# Subzone: FLORA DRIVE
# Subzone: DHOBY GHAUT
# Subzone: YISHUN SOUTH
# Subzone: SENJA
# Subzone: GEYLANG EAST
# Subzone: WOODGROVE
# Subzone: SENNETT
# Subzone: ALJUNIED
# Subzone: WOODLANDS EAST
# Subzone: NORTH COAST
# Subzone: YISHUN EAST
# Subzone: YISHUN WEST
# Subzone: TAMPINES EAST
# Subzone: BEDOK SOUTH
# Subzone: KALLANG BAHRU
# Subzone: JOO SENG
# Subzone: YISHUN WEST
# Subzone: CHOA CHU KANG NORTH
# Subzone: YISHUN WEST
# Subzone: TAMPINES EAST
# Subzone: YUNNAN
# Subzone: FABER
# Subzone: JELEBU
# Subzone: ADMIRALTY
# Subzone: TAMPINES WEST
# Subzone: CECIL
# Subzone: PLANTATION
# Subzone: SEMBAWANG EAST
# Subzone: FERNVALE
# Subzone: KANGKAR
# Subzone: YISHUN EAST
# Subzone: WOODLANDS EAST
# Subzone: WOODLANDS EAST
# Subzone: CLEMENTI WEST
# Subzone: NORTHSHORE
# Subzone: ALEXANDRA HILL
# Subzone: FRANKEL
# Subzone: TAMAN JURONG
# Subzone: SENGKANG TOWN CENTRE
# Subzone: COMPASSVALE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: RIVERVALE
# Subzone: BEDOK NORTH
# Subzone: BENCOOLEN
# Subzone: YISHUN WEST
# Subzone: TECK WHYE
# Subzone: BISHAN EAST
# Subzone: YISHUN EAST
# Subzone: WOODLANDS EAST
# Subzone: CLEMENTI CENTRAL
# Subzone: SEMBAWANG CENTRAL
# Subzone: SEMBAWANG EAST
# Subzone: TAI SENG
# Subzone: UPPER THOMSON
# Subzone: YUNNAN
# Subzone: BUKIT BATOK SOUTH
# Subzone: WOODGROVE
# Subzone: NORTHLAND
# Subzone: WOODLEIGH
# Subzone: BENDEMEER
# Subzone: TAMPINES WEST
# Subzone: YUNNAN
# Subzone: NATURE RESERVE
# Subzone: BISHAN EAST
# Subzone: RIVERVALE
# Subzone: CHONG BOON
# Subzone: HONG KAH
# Subzone: PUNGGOL FIELD
# Subzone: WOODLANDS EAST
# Subzone: TAMPINES WEST
# Subzone: TOA PAYOH CENTRAL
# Subzone: RAFFLES PLACE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: TECK WHYE
# Subzone: MARINE PARADE
# Subzone: YISHUN EAST
# Subzone: LORONG AH SOO
# Subzone: WOODGROVE
# Subzone: LORONG CHUAN
# Subzone: BISHAN EAST
# Subzone: MIDVIEW
# Subzone: CLEMENTI CENTRAL
# Subzone: FERNVALE
# Subzone: YISHUN EAST
# Subzone: TRAFALGAR
# Subzone: HILLVIEW
# Subzone: BENDEMEER
# Subzone: TAMPINES NORTH
# Subzone: FRANKEL
# Subzone: KATONG
# Subzone: PASIR RIS PARK
# Subzone: DAIRY FARM
# Subzone: LORONG AH SOO
# Subzone: SELETAR HILLS
# Subzone: BENDEMEER
# Subzone: MEI CHIN
# Subzone: SIMEI
# Subzone: RIDOUT
# Subzone: UPPER PAYA LEBAR
# Subzone: BUKIT BATOK CENTRAL
# Subzone: SEMBAWANG NORTH
# Subzone: CHONG BOON
# Subzone: FRANKEL
# Subzone: WOODLANDS EAST
# Subzone: ALJUNIED
# Subzone: SERANGOON GARDEN
# Subzone: SENNETT
# Subzone: ANCHORVALE
# Subzone: MATILDA
# Subzone: ULU PANDAN
# Subzone: POTONG PASIR
# Subzone: SEMBAWANG HILLS
# Subzone: HONG KAH NORTH
# Subzone: TAMPINES WEST
# Subzone: KOVAN
# Subzone: SEMBAWANG NORTH
# Subzone: LORONG 8 TOA PAYOH
# Subzone: CECIL
# Subzone: SERANGOON CENTRAL
# Subzone: HOUGANG EAST
# Subzone: KEMBANGAN
# Subzone: WATERWAY EAST
# Subzone: SWISS CLUB
# Subzone: SEMBAWANG CENTRAL
# Subzone: GOMBAK
# Subzone: HILLCREST
# Subzone: SENGKANG TOWN CENTRE
# Subzone: INSTITUTION HILL
# Subzone: SEMBAWANG SPRINGS
# Subzone: CLEMENTI NORTH
# Subzone: FERNVALE
# Subzone: NORTHLAND
# Subzone: BEDOK SOUTH
# Subzone: WATERWAY EAST
# Subzone: YISHUN SOUTH
# Subzone: SEMBAWANG NORTH
# Subzone: PASIR RIS WEST
# Subzone: MARYMOUNT
# Subzone: BEDOK RESERVOIR
# Subzone: WOODLANDS WEST
# Subzone: TOH GUAN
# Subzone: TOA PAYOH WEST
# Subzone: SENTOSA
# Subzone: FAJAR
# Subzone: TOA PAYOH CENTRAL
# Subzone: SIMEI
# Subzone: ANAK BUKIT
# Subzone: BEDOK SOUTH
# Subzone: TECK WHYE
# Subzone: GEYLANG EAST
# Subzone: PASIR RIS CENTRAL
# Subzone: ONE NORTH
# Subzone: YISHUN WEST
# Subzone: KENT RIDGE
# Subzone: HILLCREST
# Subzone: SUNSET WAY
# Subzone: MARYMOUNT
# Subzone: YIO CHU KANG
# Subzone: KHATIB
# Subzone: YISHUN WEST
# Subzone: TAMPINES EAST
# Subzone: YISHUN WEST
# Subzone: HILLVIEW
# Subzone: TAMPINES WEST
# Subzone: BANGKIT
# Subzone: CHOA CHU KANG NORTH
# Subzone: RIVERVALE
# Subzone: YUNNAN
# Subzone: JURONG GATEWAY
# Subzone: RIVERVALE
# Subzone: BRADDELL
# Subzone: BEDOK NORTH
# Subzone: WOODLANDS SOUTH
# Subzone: TAMPINES WEST
# Subzone: PASIR RIS WEST
# Subzone: TAMPINES EAST
# Subzone: BIDADARI
# Subzone: ANAK BUKIT
# Subzone: PASIR RIS WEST
# Subzone: PASIR RIS PARK
# Subzone: MANDAI ESTATE
# Subzone: SEMBAWANG CENTRAL
# Subzone: ALJUNIED
# Subzone: KAMPONG UBI
# Subzone: HILLVIEW
# Subzone: SERANGOON GARDEN
# Subzone: JOO SENG
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: WOODLEIGH
# Subzone: PEARL'S HILL
# Subzone: WOODLANDS WEST
# Subzone: PENG SIANG
# Subzone: MOUNTBATTEN
# Subzone: CLEMENTI NORTH
# Subzone: BEDOK SOUTH
# Subzone: YISHUN SOUTH
# Subzone: TAMPINES WEST
# Subzone: NATURE RESERVE
# Subzone: POTONG PASIR
# Subzone: CHINATOWN
# Subzone: SAUJANA
# Subzone: SENNETT
# Subzone: TAMPINES WEST
# Subzone: ALJUNIED
# Subzone: GEYLANG BAHRU
# Subzone: COMPASSVALE
# Subzone: BEDOK NORTH
# Subzone: JURONG WEST CENTRAL
# Subzone: KAMPONG UBI
# Subzone: ALJUNIED
# Subzone: PUNGGOL FIELD
# Subzone: WOODLANDS EAST
# Subzone: PASIR PANJANG 2
# Subzone: KATONG
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: YISHUN SOUTH
# Subzone: LOWER SELETAR
# Subzone: NORTHLAND
# Subzone: KANGKAR
# Subzone: ANAK BUKIT
# Subzone: PASIR RIS CENTRAL
# Subzone: FERNVALE
# Subzone: SHANGRI-LA
# Subzone: XILIN
# Subzone: FARRER COURT
# Subzone: KOVAN
# Subzone: KALLANG BAHRU
# Subzone: HONG KAH
# Subzone: ADMIRALTY
# Subzone: JELEBU
# Subzone: BUKIT BATOK SOUTH
# Subzone: PASIR RIS DRIVE
# Subzone: MARINE PARADE
# Subzone: CHATSWORTH
# Subzone: GARDEN
# Subzone: CLEMENTI NORTH
# Subzone: SEMBAWANG SPRINGS
# Subzone: MANDAI ESTATE
# Subzone: SEMBAWANG SPRINGS
# Subzone: SEMBAWANG HILLS
# Subzone: UPPER THOMSON
# Subzone: NORTHSHORE
# Subzone: SELETAR HILLS
# Subzone: WATERWAY EAST
# Subzone: JURONG WEST CENTRAL
# Subzone: SENNETT
# Subzone: SELETAR
# Subzone: YEW TEE
# Subzone: KATONG
# Subzone: DEPOT ROAD
# Subzone: SENTOSA
# Subzone: YISHUN SOUTH
# Subzone: HONG KAH
# Subzone: HILLCREST
# Subzone: MARGARET DRIVE
# Subzone: TAGORE
# Subzone: ANAK BUKIT
# Subzone: KATONG
# Subzone: PASIR RIS WEST
# Subzone: YUNNAN
# Subzone: KENT RIDGE
# Subzone: TAMAN JURONG
# Subzone: TOA PAYOH CENTRAL
# Subzone: PASIR RIS DRIVE
# Subzone: PASIR RIS CENTRAL
# Subzone: SERANGOON CENTRAL
# Subzone: PASIR RIS DRIVE
# Subzone: PASIR RIS CENTRAL
# Subzone: SERANGOON CENTRAL
# Subzone: PASIR RIS DRIVE
# Subzone: SERANGOON GARDEN
# Subzone: PASIR RIS WEST
# Subzone: SERANGOON GARDEN
# Subzone: BIDADARI
# Subzone: MACPHERSON
# Subzone: GEYLANG EAST
# Subzone: ALJUNIED
# Subzone: MARINE PARADE
# Subzone: GEYLANG EAST
# Subzone: ALJUNIED
# Subzone: MARINE PARADE
# Subzone: KIM KEAT
# Subzone: SENNETT
# Subzone: BENDEMEER
# Subzone: BRADDELL
# Subzone: PEI CHUN
# Subzone: BOON TECK
# Subzone: KIM KEAT
# Subzone: TOA PAYOH CENTRAL
# Subzone: GEYLANG BAHRU
# Subzone: ANAK BUKIT
# Subzone: YUHUA EAST
# Subzone: MACPHERSON
# Subzone: MARITIME SQUARE
# Subzone: MAXWELL
# Subzone: SEMBAWANG NORTH
# Subzone: TOA PAYOH CENTRAL
# Subzone: KAKI BUKIT
# Subzone: KAKI BUKIT
# Subzone: KAKI BUKIT
# Subzone: KAKI BUKIT
# Subzone: KAKI BUKIT
# Subzone: ADMIRALTY
# Subzone: TEBAN GARDENS
# Subzone: COMPASSVALE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: COMPASSVALE
# Subzone: MARINE PARADE
# Subzone: UPPER THOMSON
# Subzone: BISHAN EAST
# Subzone: TEBAN GARDENS
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: ANCHORVALE
# Subzone: ANCHORVALE
# Subzone: ANCHORVALE
# Subzone: SENNETT
# Subzone: JOO SENG
# Subzone: POTONG PASIR
# Subzone: YISHUN SOUTH
# Subzone: YISHUN SOUTH
# Subzone: YISHUN SOUTH
# Subzone: MOULMEIN
# Subzone: BALESTIER
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: SAUJANA
# Subzone: YUNNAN
# Subzone: CHOA CHU KANG NORTH
# Subzone: WOODLANDS EAST
# Subzone: GUILIN
# Subzone: MIDVIEW
# Subzone: BUKIT MERAH
# Subzone: CLEMENTI WOODS
# Subzone: MOUNTBATTEN
# Subzone: ONE NORTH
# Subzone: ONE TREE HILL
# Subzone: MOUNT EMILY
# Subzone: ONE NORTH
# Subzone: BOULEVARD
# Subzone: PASIR PANJANG 1
# Subzone: WOODGROVE
# Subzone: MIDVIEW
# Subzone: WOODGROVE
# Subzone: KEAT HONG
# Subzone: SENJA
# Subzone: HOLLAND ROAD
# Subzone: PENG SIANG
# Subzone: SAUJANA
# Subzone: CHOA CHU KANG NORTH
# Subzone: KEAT HONG
# Subzone: KEAT HONG
# Subzone: PASIR RIS DRIVE
# Subzone: TOH TUCK
# Subzone: TIONG BAHRU
# Subzone: ONE NORTH
# Subzone: RAFFLES PLACE
# Subzone: CLARKE QUAY
# Subzone: PASIR PANJANG 2
# Subzone: PASIR RIS WEST
# Subzone: CHOA CHU KANG NORTH
# Subzone: TECK WHYE
# Subzone: MARITIME SQUARE
# Subzone: TOA PAYOH CENTRAL
# Subzone: SELETAR HILLS
# Subzone: SELETAR HILLS
# Subzone: BRICKWORKS
# Subzone: SEMBAWANG SPRINGS
# Subzone: LOWER SELETAR
# Subzone: NORTHLAND
# Subzone: PUNGGOL FIELD
# Subzone: WENYA
# Subzone: KAMPONG JAVA
# Subzone: KEAT HONG
# Subzone: YEW TEE
# Subzone: PENG SIANG
# Subzone: TAMPINES EAST
# Subzone: KEAT HONG
# Subzone: YUNNAN
# Subzone: TOH GUAN
# Subzone: BEDOK NORTH
# Subzone: SIGLAP
# Subzone: SEMBAWANG SPRINGS
# Subzone: MARINE PARADE
# Subzone: CLEMENTI WOODS
# Subzone: MIDVIEW
# Subzone: SHANGRI-LA
# Subzone: KEBUN BAHRU
# Subzone: BEDOK NORTH
# Subzone: FLORA DRIVE
# Subzone: SERANGOON GARDEN
# Subzone: BEDOK SOUTH
# Subzone: SERANGOON GARDEN
# Subzone: SERANGOON GARDEN
# Subzone: RIVERVALE
# Subzone: RIVERVALE
# Subzone: RIVERVALE
# Subzone: RIVERVALE
# Subzone: MATILDA
# Subzone: MATILDA
# Subzone: NORTHSHORE
# Subzone: NORTHSHORE
# Subzone: WATERWAY EAST
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: ANAK BUKIT
# Subzone: WATERWAY EAST
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: LORONG AH SOO
# Subzone: HOUGANG EAST
# Subzone: SEMBAWANG SPRINGS
# Subzone: SEMBAWANG SPRINGS
# Subzone: YISHUN EAST
# Subzone: YISHUN WEST
# Subzone: NORTHLAND
# Subzone: ANAK BUKIT
# Subzone: ANAK BUKIT
# Subzone: YISHUN EAST
# Subzone: YISHUN EAST
# Subzone: LOWER SELETAR
# Subzone: YISHUN EAST
# Subzone: YISHUN SOUTH
# Subzone: KHATIB
# Subzone: MARINA CENTRE
# Subzone: TAMPINES EAST
# Subzone: RAFFLES PLACE
# Subzone: KAMPONG UBI
# Subzone: CLEMENTI WOODS
# Subzone: PEARL'S HILL
# Subzone: KAMPONG TIONG BAHRU
# Subzone: BUKIT HO SWEE
# Subzone: HENDERSON HILL
# Subzone: MARGARET DRIVE
# Subzone: CLEMENTI NORTH
# Subzone: CLEMENTI CENTRAL
# Subzone: CHINATOWN
# Subzone: GUILIN
# Subzone: HONG KAH NORTH
# Subzone: BUKIT BATOK SOUTH
# Subzone: NORTHSHORE
# Subzone: BOAT QUAY
# Subzone: CHINATOWN
# Subzone: SEMBAWANG CENTRAL
# Subzone: PASIR PANJANG 2
# Subzone: HILLVIEW
# Subzone: YUNNAN
# Subzone: PASIR PANJANG 1
# Subzone: PASIR RIS WEST
# Subzone: KOVAN
# Subzone: TAMPINES EAST
# Subzone: CHOA CHU KANG NORTH
# Subzone: WOODGROVE
# Subzone: PASIR RIS WEST
# Subzone: MOULMEIN
# Subzone: ALEXANDRA HILL
# Subzone: KHATIB
# Subzone: MACPHERSON
# Subzone: SERANGOON CENTRAL
# Subzone: TAMPINES NORTH
# Subzone: SERANGOON NORTH
# Subzone: BEDOK SOUTH
# Subzone: BOON TECK
# Subzone: SAUJANA
# Subzone: WOODLANDS WEST
# Subzone: CLEMENTI WEST
# Subzone: KEAT HONG
# Subzone: PASIR PANJANG 2
# Subzone: BEDOK SOUTH
# Subzone: SENNETT
# Subzone: BENDEMEER
# Subzone: FARRER COURT
# Subzone: FARRER COURT
# Subzone: TAMPINES EAST
# Subzone: ANG MO KIO TOWN CENTRE
# Subzone: UPPER PAYA LEBAR
# Subzone: JELEBU
# Subzone: TAMPINES WEST
# Subzone: CHOA CHU KANG NORTH
# Subzone: CHOA CHU KANG NORTH
# Subzone: TOH GUAN
# Subzone: BENDEMEER
# Subzone: GEYLANG BAHRU
# Subzone: CLEMENTI WOODS
# Subzone: WEST COAST
# Subzone: ONE NORTH
# Subzone: YIO CHU KANG
# Subzone: MARGARET DRIVE
# Subzone: TAMPINES EAST
# Subzone: MARINE PARADE
# Subzone: MARITIME SQUARE
# Subzone: KOVAN
# Subzone: HILLVIEW
# Subzone: LEONIE HILL
# Subzone: MOUNTBATTEN
# Subzone: FRANKEL
# Subzone: NORTHLAND
# Subzone: CLEANTECH
# Subzone: TAMAN JURONG
# Subzone: NORTHSHORE
# Subzone: SELETAR HILLS
# Subzone: GOMBAK
# Subzone: SEMBAWANG SPRINGS
# Subzone: BALESTIER
# Subzone: NASSIM
# Subzone: BEDOK RESERVOIR
# Subzone: KAKI BUKIT
# Subzone: MOULMEIN
# Subzone: MOULMEIN
# Subzone: RAFFLES PLACE
# Subzone: HOLLAND ROAD
# Subzone: KATONG
# Subzone: TECK WHYE
# Subzone: LORONG CHUAN
# Subzone: ANAK BUKIT
# Subzone: NASSIM
# Subzone: HILLCREST
# Subzone: WOODLANDS EAST
# Subzone: HONG KAH
# Subzone: HONG KAH
# Subzone: UPPER THOMSON
# Subzone: BRADDELL
# Subzone: LORONG AH SOO
# Subzone: TAMPINES EAST
# Subzone: CORONATION ROAD
# Subzone: TANJONG RHU
# Subzone: BAYSHORE
# Subzone: OXLEY
# Subzone: BEDOK SOUTH
# Subzone: SERANGOON NORTH
# Subzone: SERANGOON NORTH
# Subzone: SINGAPORE POLYTECHNIC
# Subzone: ONE NORTH
# Subzone: CAIRNHILL
# Subzone: ALEXANDRA HILL
# Subzone: CHENG SAN
# Subzone: KEBUN BAHRU
# Subzone: KEBUN BAHRU
# Subzone: SHANGRI-LA
# Subzone: YISHUN WEST
# Subzone: NORTHLAND
# Subzone: NORTHLAND
# Subzone: YISHUN WEST
# Subzone: BANGKIT
# Subzone: JELEBU
# Subzone: BANGKIT
# Subzone: FAJAR
# Subzone: TAMPINES EAST
# Subzone: TAMPINES WEST
# Subzone: TAMPINES EAST
# Subzone: TAMPINES WEST
# Subzone: TAMPINES WEST
# Subzone: MARGARET DRIVE
# Subzone: MARYMOUNT
# Subzone: ALEXANDRA HILL
# Subzone: MARGARET DRIVE
# Subzone: MEI CHIN
# Subzone: MARGARET DRIVE
# Subzone: TAGORE
# Subzone: SPRINGLEAF
# Subzone: ANG MO KIO TOWN CENTRE
# Subzone: INTERNATIONAL BUSINESS PARK
# Subzone: ANAK BUKIT
# Subzone: JURONG GATEWAY
# Subzone: UPPER THOMSON
# Subzone: TAI SENG
# Subzone: MATILDA
# Subzone: PASIR RIS WEST
# Subzone: BEDOK NORTH
# Subzone: JURONG WEST CENTRAL
# Subzone: TRAFALGAR
# Subzone: TRAFALGAR
# Subzone: YEW TEE
# Subzone: MIDVIEW
# Subzone: YISHUN WEST
# Subzone: GEYLANG EAST
# Subzone: YUHUA EAST
# Subzone: TAMAN JURONG
# Subzone: JURONG WEST CENTRAL
# Subzone: TEBAN GARDENS
# Subzone: YUNNAN
# Subzone: BENDEMEER
# Subzone: KEMBANGAN
# Subzone: XILIN
# Subzone: FRANKEL
# Subzone: BAYSHORE
# Subzone: LORONG AH SOO
# Subzone: KATONG
# Subzone: ALJUNIED
# Subzone: KALLANG BAHRU
# Subzone: TAGORE
# Subzone: YIO CHU KANG EAST
# Subzone: PUNGGOL FIELD
# Subzone: YISHUN SOUTH
# Subzone: PUNGGOL FIELD
# Subzone: YISHUN EAST
# Subzone: SAUJANA
# Subzone: YISHUN EAST
# Subzone: YISHUN EAST
# Subzone: YISHUN EAST
# Subzone: YISHUN EAST
# Subzone: DUNEARN
# Subzone: TOA PAYOH CENTRAL
# Subzone: HOLLAND DRIVE
# Subzone: BOULEVARD
# Subzone: LAVENDER
# Subzone: TOA PAYOH CENTRAL
# Subzone: HONG KAH
# Subzone: BIDADARI
# Subzone: SEMBAWANG EAST
# Subzone: JURONG WEST CENTRAL
# Subzone: SWISS CLUB
# Subzone: TELOK BLANGAH WAY
# Subzone: TAMPINES EAST
# Subzone: BOON KENG
# Subzone: HONG KAH
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SERANGOON GARDEN
# Subzone: TAMPINES NORTH
# Subzone: KIM KEAT
# Subzone: PEARL'S HILL
# Subzone: MARINE PARADE
# Subzone: WOODGROVE
# Subzone: ANCHORVALE
# Subzone: FAJAR
# Subzone: BENDEMEER
# Subzone: KEAT HONG
# Subzone: HONG KAH
# Subzone: MATILDA
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: BUKIT HO SWEE
# Subzone: MARYMOUNT
# Subzone: FERNVALE
# Subzone: TRAFALGAR
# Subzone: HOUGANG WEST
# Subzone: SEMBAWANG NORTH
# Subzone: YEW TEE
# Subzone: BEDOK NORTH
# Subzone: CORONATION ROAD
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: BRICKWORKS
# Subzone: BEDOK NORTH
# Subzone: WOODLANDS EAST
# Subzone: RIDOUT
# Subzone: SPRINGLEAF
# Subzone: TAMPINES NORTH
# Subzone: ALJUNIED
# Subzone: ANAK BUKIT
# Subzone: ALEXANDRA HILL
# Subzone: GEYLANG EAST
# Subzone: PASIR RIS WEST
# Subzone: ANCHORVALE
# Subzone: HILLCREST
# Subzone: SEMBAWANG EAST
# Subzone: TAMPINES EAST
# Subzone: TELOK BLANGAH DRIVE
# Subzone: SHANGRI-LA
# Subzone: SENGKANG TOWN CENTRE
# Subzone: HILLVIEW
# Subzone: MARGARET DRIVE
# Subzone: SERANGOON GARDEN
# Subzone: GHIM MOH
# Subzone: HOUGANG EAST
# Subzone: WATERWAY EAST
# Subzone: TAMPINES EAST
# Subzone: HONG KAH
# Subzone: WATERWAY EAST
# Subzone: SERANGOON GARDEN
# Subzone: PASIR RIS PARK
# Subzone: WOODGROVE
# Subzone: NORTHLAND
# Subzone: DAIRY FARM
# Subzone: FERNVALE
# Subzone: FRANKEL
# Subzone: BALESTIER
# Subzone: UPPER THOMSON
# Subzone: CHATSWORTH
# Subzone: GHIM MOH
# Subzone: KOVAN
# Subzone: PENG SIANG
# Subzone: PUNGGOL FIELD
# Subzone: TAMPINES EAST
# Subzone: PUNGGOL FIELD
# Subzone: PUNGGOL FIELD
# Subzone: WOODLANDS WEST
# Subzone: SENNETT
# Subzone: WOODLANDS REGIONAL CENTRE
# Subzone: WATERWAY EAST
# Subzone: BUKIT BATOK SOUTH
# Subzone: TAI SENG
# Subzone: BALESTIER
# Subzone: YUHUA EAST
# Subzone: YIO CHU KANG
# Subzone: FERNVALE
# Subzone: HENDERSON HILL
# Subzone: BALESTIER
# Subzone: HONG KAH
# Subzone: JOO SENG
# Subzone: PLANTATION
# Subzone: ALJUNIED
# Subzone: CLEMENTI CENTRAL
# Subzone: FRANKEL
# Subzone: CHANGI AIRPORT
# Subzone: SERANGOON CENTRAL
# Subzone: PASIR RIS CENTRAL
# Subzone: PASIR RIS DRIVE
# Subzone: PASIR RIS DRIVE
# Subzone: MOUNTBATTEN
# Subzone: GREENWOOD PARK
# Subzone: JOO SENG
# Subzone: TAI SENG
# Subzone: LORONG AH SOO
# Subzone: KALLANG WAY
# Subzone: BEDOK NORTH
# Subzone: MOULMEIN
# Subzone: TRAFALGAR
# Subzone: WATERWAY EAST
# Subzone: PASIR RIS DRIVE
# Subzone: WOODLANDS EAST
# Subzone: JURONG WEST CENTRAL
# Subzone: PEI CHUN
# Subzone: CLEMENTI CENTRAL
# Subzone: YUNNAN
# Subzone: CHINATOWN
# Subzone: PUNGGOL FIELD
# Subzone: CLIFFORD PIER
# Subzone: LOWER SELETAR
# Subzone: YISHUN CENTRAL
# Subzone: TOH GUAN
# Subzone: TAMPINES WEST
# Subzone: MARGARET DRIVE
# Subzone: MEI CHIN
# Subzone: BOON KENG
# Subzone: KEMBANGAN
# Subzone: KANGKAR
# Subzone: KEBUN BAHRU
# Subzone: CHONG BOON
# Subzone: FRANKEL
# Subzone: BEDOK RESERVOIR
# Subzone: RIVERVALE
# Subzone: HOUGANG EAST
# Subzone: BALESTIER
# Subzone: KAMPONG UBI
# Subzone: KEBUN BAHRU
# Subzone: TOA PAYOH CENTRAL
# Subzone: BEDOK NORTH
# Subzone: SIMEI
# Subzone: BOON LAY PLACE
# Subzone: KEAT HONG
# Subzone: WOODLANDS EAST
# Subzone: ANAK BUKIT
# Subzone: KAMPONG JAVA
# Subzone: HONG KAH NORTH
# Subzone: FRANKEL
# Subzone: WATERWAY EAST
# Subzone: WATERWAY EAST
# Subzone: BEDOK NORTH
# Subzone: TELOK BLANGAH DRIVE
# Subzone: DEPOT ROAD
# Subzone: SEMBAWANG CENTRAL
# Subzone: CHENG SAN
# Subzone: WATERWAY EAST
# Subzone: JELEBU
# Subzone: TAI SENG
# Subzone: SERANGOON NORTH
# Subzone: NORTHSHORE
# Subzone: PASIR RIS DRIVE
# Subzone: BISHAN EAST
# Subzone: GUILIN
# Subzone: MARINE PARADE
# Subzone: BENDEMEER
# Subzone: BEDOK SOUTH
# Subzone: INTERNATIONAL BUSINESS PARK
# Subzone: LORONG AH SOO
# Subzone: WEST COAST
# Subzone: BISHAN EAST
# Subzone: TRAFALGAR
# Subzone: KATONG
# Subzone: FRANKEL
# Subzone: COMPASSVALE
# Subzone: KAKI BUKIT
# Subzone: WOODLANDS SOUTH
# Subzone: RIVERVALE
# Subzone: WATERWAY EAST
# Subzone: BENDEMEER
# Subzone: WOODLANDS EAST
# Subzone: DUNEARN
# Subzone: JURONG WEST CENTRAL
# Subzone: CHENG SAN
# Subzone: SERANGOON GARDEN
# Subzone: BRICKWORKS
# Subzone: MOUNTBATTEN
# Subzone: TANGLIN HALT
# Subzone: ANCHORVALE
# Subzone: GOODWOOD PARK
# Subzone: HENDERSON HILL
# Subzone: GOODWOOD PARK
# Subzone: RIVERVALE
# Subzone: TAI SENG
# Subzone: YISHUN WEST
# Subzone: TAMPINES NORTH
# Subzone: ANAK BUKIT
# Subzone: WOODLANDS EAST
# Subzone: SERANGOON CENTRAL
# Subzone: YUNNAN
# Subzone: KEBUN BAHRU
# Subzone: WOODLANDS EAST
# Subzone: WATERWAY EAST
# Subzone: YISHUN EAST
# Subzone: HOUGANG EAST
# Subzone: SEMBAWANG CENTRAL
# Subzone: YUNNAN
# Subzone: YISHUN SOUTH
# Subzone: SELETAR HILLS
# Subzone: YIO CHU KANG WEST
# Subzone: DOVER
# Subzone: CHENG SAN
# Subzone: VICTORIA
# Subzone: HOUGANG CENTRAL
# Subzone: LEEDON PARK
# Subzone: ALJUNIED
# Subzone: SENJA
# Subzone: SENJA
# Subzone: BEDOK RESERVOIR
# Subzone: HOUGANG EAST
# Subzone: SENGKANG TOWN CENTRE
# Subzone: CLEMENTI CENTRAL
# Subzone: UPPER THOMSON
# Subzone: BOON KENG
# Subzone: TANGLIN HALT
# Subzone: WENYA
# Subzone: ANCHORVALE
# Subzone: CHOA CHU KANG NORTH
# Subzone: JELEBU
# Subzone: BUKIT BATOK WEST
# Subzone: LORONG AH SOO
# Subzone: BRICKWORKS
# Subzone: BUKIT BATOK CENTRAL
# Subzone: BUKIT BATOK CENTRAL
# Subzone: BEDOK NORTH
# Subzone: TRAFALGAR
# Subzone: PASIR RIS PARK
# Subzone: FLORA DRIVE
# Subzone: KOVAN
# Subzone: GEYLANG EAST
# Subzone: TAGORE
# Subzone: BEDOK NORTH
# Subzone: BEDOK NORTH
# Subzone: BEDOK SOUTH
# Subzone: MEI CHIN
# Subzone: KEMBANGAN
# Subzone: BEDOK SOUTH
# Subzone: KEMBANGAN
# Subzone: BAYSHORE
# Subzone: BEDOK NORTH
# Subzone: TAMPINES WEST
# Subzone: FABER
# Subzone: MOUNTBATTEN
# Subzone: GEYLANG EAST
# Subzone: TANJONG RHU
# Subzone: WOODLEIGH
# Subzone: UPPER PAYA LEBAR
# Subzone: LORONG CHUAN
# Subzone: FARRER PARK
# Subzone: NORTH COAST
# Subzone: MATILDA
# Subzone: CLEMENTI NORTH
# Subzone: WATERWAY EAST
# Subzone: MARYMOUNT
# Subzone: CHOA CHU KANG NORTH
# Subzone: FRANKEL
# Subzone: SERANGOON GARDEN
# Subzone: JURONG WEST CENTRAL
# Subzone: CORONATION ROAD
# Subzone: FAJAR
# Subzone: MIDVIEW
# Subzone: PASIR RIS DRIVE
# Subzone: HOLLAND DRIVE
# Subzone: TAMPINES EAST
# Subzone: GHIM MOH
# Subzone: PENG SIANG
# Subzone: COMMONWEALTH
# Subzone: TOWNSVILLE
# Subzone: PENG SIANG
# Subzone: PASIR RIS WEST
# Subzone: ADMIRALTY
# Subzone: YUNNAN
# Subzone: GEYLANG EAST
# Subzone: KEMBANGAN
# Subzone: WOODGROVE
# Subzone: WOODGROVE
# Subzone: WOODLANDS SOUTH
# Subzone: WOODGROVE
# Subzone: MIDVIEW
# Subzone: WOODLANDS SOUTH
# Subzone: YUNNAN
# Subzone: TECK WHYE
# Subzone: TECK WHYE
# Subzone: TECK WHYE
# Subzone: TECK WHYE
# Subzone: SEMBAWANG CENTRAL
# Subzone: SEMBAWANG NORTH
# Subzone: SEMBAWANG CENTRAL
# Subzone: GUILIN
# Subzone: GUILIN
# Subzone: BUKIT BATOK WEST
# Subzone: BUKIT BATOK CENTRAL
# Subzone: BOON LAY PLACE
# Subzone: JURONG WEST CENTRAL
# Subzone: KEMBANGAN
# Subzone: KEMBANGAN
# Subzone: COMPASSVALE
# Subzone: KALLANG BAHRU
# Subzone: KEMBANGAN
# Subzone: BALESTIER
# Subzone: TAMPINES EAST
# Subzone: XILIN
# Subzone: UPPER THOMSON
# Subzone: YISHUN EAST
# Subzone: KEMBANGAN
# Subzone: BENDEMEER
# Subzone: BALESTIER
# Subzone: YEW TEE
# Subzone: TOA PAYOH CENTRAL
# Subzone: SAUJANA
# Subzone: MANDAI EAST
# Subzone: KAMPONG BUGIS
# Subzone: FRANKEL
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: RIDOUT
# Subzone: BRADDELL
# Subzone: ALJUNIED
# Subzone: JURONG WEST CENTRAL
# Subzone: PASIR RIS CENTRAL
# Subzone: CLEMENTI NORTH
# Subzone: MACPHERSON
# Subzone: BUKIT BATOK EAST
# Subzone: LORONG CHUAN
# Subzone: YEW TEE
# Subzone: BUKIT HO SWEE
# Subzone: YISHUN CENTRAL
# Subzone: WOODLANDS EAST
# Subzone: HOUGANG WEST
# Subzone: FRANKEL
# Subzone: KOVAN
# Subzone: BEDOK SOUTH
# Subzone: HOLLAND DRIVE
# Subzone: SAUJANA
# Subzone: ALEXANDRA NORTH
# Subzone: WOODLANDS EAST
# Subzone: MOUNTBATTEN
# Subzone: KALLANG WAY
# Subzone: SEMBAWANG SPRINGS
# Subzone: SEMBAWANG CENTRAL
# Subzone: BEDOK SOUTH
# Subzone: ALJUNIED
# Subzone: TELOK BLANGAH DRIVE
# Subzone: TELOK BLANGAH DRIVE
# Subzone: SELETAR HILLS
# Subzone: TEBAN GARDENS
# Subzone: TAMPINES EAST
# Subzone: CHENG SAN
# Subzone: YIO CHU KANG WEST
# Subzone: MATILDA
# Subzone: TRAFALGAR
# Subzone: TANJONG RHU
# Subzone: SINGAPORE GENERAL HOSPITAL
# Subzone: ALJUNIED
# Subzone: JURONG GATEWAY
# Subzone: CLEMENTI WOODS
# Subzone: SAUJANA
# Subzone: FERNVALE
# Subzone: WOODLANDS SOUTH
# Subzone: SEMBAWANG EAST
# Subzone: NATIONAL UNIVERSITY OF S'PORE
# Subzone: TAMPINES WEST
# Subzone: MOUNTBATTEN
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SEMBAWANG EAST
# Subzone: NORTHSHORE
# Subzone: KEAT HONG
# Subzone: NORTHSHORE
# Subzone: TRAFALGAR
# Subzone: TELOK BLANGAH RISE
# Subzone: SERANGOON NORTH
# Subzone: MATILDA
# Subzone: PUNGGOL FIELD
# Subzone: KANGKAR
# Subzone: KANGKAR
# Subzone: SEMBAWANG NORTH
# Subzone: ANG MO KIO TOWN CENTRE
# Subzone: BISHAN EAST
# Subzone: LORONG AH SOO
# Subzone: NORTHSHORE
# Subzone: MOULMEIN
# Subzone: CORONATION ROAD
# Subzone: BUKIT BATOK CENTRAL
# Subzone: YISHUN SOUTH
# Subzone: FAJAR
# Subzone: BUKIT BATOK EAST
# Subzone: KALLANG BAHRU
# Subzone: TRAFALGAR
# Subzone: RIVERVALE
# Subzone: ULU PANDAN
# Subzone: OXLEY
# Subzone: BANGKIT
# Subzone: KEMBANGAN
# Subzone: KATONG
# Subzone: BRICKWORKS
# Subzone: SIMEI
# Subzone: SEMBAWANG HILLS
# Subzone: BENDEMEER
# Subzone: BRICKWORKS
# Subzone: PASIR RIS DRIVE
# Subzone: LOYANG WEST
# Subzone: KAMPONG UBI
# Subzone: SENNETT
# Subzone: KANGKAR
# Subzone: MOUNT EMILY
# Subzone: SERANGOON CENTRAL
# Subzone: TAMPINES WEST
# Subzone: BALESTIER
# Subzone: TAMPINES EAST
# Subzone: HONG KAH NORTH
# Subzone: BISHAN EAST
# Subzone: SERANGOON CENTRAL
# Subzone: BRICKWORKS
# Subzone: JURONG WEST CENTRAL
# Subzone: WATERWAY EAST
# Subzone: CHENG SAN
# Subzone: PHILLIP
# Subzone: TIONG BAHRU STATION
# Subzone: TAMPINES EAST
# Subzone: SIMEI
# Subzone: BEDOK NORTH
# Subzone: KOVAN
# Subzone: PENG SIANG
# Subzone: BEDOK NORTH
# Subzone: BEDOK NORTH
# Subzone: YUHUA EAST
# Subzone: MARGARET DRIVE
# Subzone: WATERWAY EAST
# Subzone: MARYMOUNT
# Subzone: JURONG WEST CENTRAL
# Subzone: WOODLANDS EAST
# Subzone: WOODLANDS WEST
# Subzone: SEMBAWANG EAST
# Subzone: ADMIRALTY
# Subzone: HENDERSON HILL
# Subzone: BEDOK NORTH
# Subzone: YISHUN SOUTH
# Subzone: PUNGGOL FIELD
# Subzone: UPPER THOMSON
# Subzone: TAMPINES EAST
# Subzone: HONG KAH
# Subzone: BOON KENG
# Subzone: PENG SIANG
# Subzone: KEAT HONG
# Subzone: ANAK BUKIT
# Subzone: PEI CHUN
# Subzone: TOA PAYOH CENTRAL
# Subzone: TELOK BLANGAH WAY
# Subzone: HOUGANG WEST
# Subzone: MACPHERSON
# Subzone: TAMPINES EAST
# Subzone: CHONG BOON
# Subzone: PASIR RIS DRIVE
# Subzone: BEDOK NORTH
# Subzone: TAMPINES WEST
# Subzone: PUNGGOL FIELD
# Subzone: PENG SIANG
# Subzone: HOUGANG WEST
# Subzone: CLEMENTI WOODS
# Subzone: TAMAN JURONG
# Subzone: TAMAN JURONG
# Subzone: WOODLANDS EAST
# Subzone: BISHAN EAST
# Subzone: YISHUN EAST
# Subzone: CHENG SAN
# Subzone: BRICKWORKS
# Subzone: BRICKWORKS
# Subzone: KEAT HONG
# Subzone: YISHUN EAST
# Subzone: TRAFALGAR
# Subzone: WOODLANDS EAST
# Subzone: YIO CHU KANG WEST
# Subzone: PASIR RIS CENTRAL
# Subzone: TAMPINES WEST
# Subzone: KEAT HONG
# Subzone: BENDEMEER
# Subzone: YISHUN EAST
# Subzone: BOON TECK
# Subzone: PENG SIANG
# Subzone: BEDOK NORTH
# Subzone: BEDOK NORTH
# Subzone: WOODLANDS EAST
# Subzone: TAMPINES EAST
# Subzone: SERANGOON NORTH
# Subzone: NORTH COAST
# Subzone: YUHUA EAST
# Subzone: YUHUA EAST
# Subzone: JURONG WEST CENTRAL
# Subzone: GHIM MOH
# Subzone: BEDOK NORTH
# Subzone: WOODLANDS WEST
# Subzone: CLEMENTI WOODS
# Subzone: HOUGANG EAST
# Subzone: HOUGANG WEST
# Subzone: KANGKAR
# Subzone: YUHUA EAST
# Subzone: YEW TEE
# Subzone: HOUGANG EAST
# Subzone: WATERWAY EAST
# Subzone: CLEMENTI NORTH
# Subzone: HOLLAND DRIVE
# Subzone: TANGLIN HALT
# Subzone: HOLLAND DRIVE
# Subzone: BOON TECK
# Subzone: TOA PAYOH WEST
# Subzone: TOA PAYOH CENTRAL
# Subzone: HOUGANG WEST
# Subzone: TAMPINES NORTH
# Subzone: TOWNSVILLE
# Subzone: TOWNSVILLE
# Subzone: SHANGRI-LA
# Subzone: PASIR RIS WEST
# Subzone: BEDOK NORTH
# Subzone: TAMPINES WEST
# Subzone: TAMPINES WEST
# Subzone: CLEMENTI NORTH
# Subzone: TOH GUAN
# Subzone: BUKIT BATOK SOUTH
# Subzone: CLEMENTI WEST
# Subzone: TAMAN JURONG
# Subzone: UPPER PAYA LEBAR
# Subzone: YIO CHU KANG WEST
# Subzone: HONG KAH NORTH
# Subzone: KEAT HONG
# Subzone: SERANGOON NORTH
# Subzone: TEBAN GARDENS
# Subzone: YUNNAN
# Subzone: SENJA
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: FAJAR
# Subzone: JURONG WEST CENTRAL
# Subzone: YEW TEE
# Subzone: HONG KAH NORTH
# Subzone: KEAT HONG
# Subzone: BANGKIT
# Subzone: PASIR RIS CENTRAL
# Subzone: MATILDA
# Subzone: PUNGGOL FIELD
# Subzone: YIO CHU KANG WEST
# Subzone: KOVAN
# Subzone: HOUGANG WEST
# Subzone: TRAFALGAR
# Subzone: HOUGANG WEST
# Subzone: FRANKEL
# Subzone: MOUNTBATTEN
# Subzone: ANCHORVALE
# Subzone: ANCHORVALE
# Subzone: ANCHORVALE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: ANCHORVALE
# Subzone: TAMAN JURONG
# Subzone: TAMAN JURONG
# Subzone: WOODGROVE
# Subzone: WOODGROVE
# Subzone: WOODLANDS WEST
# Subzone: ALEXANDRA HILL
# Subzone: SIMEI
# Subzone: TAMPINES EAST
# Subzone: SIMEI
# Subzone: TAMPINES EAST
# Subzone: TOA PAYOH CENTRAL
# Subzone: SHANGRI-LA
# Subzone: TOWNSVILLE
# Subzone: CHENG SAN
# Subzone: TOWNSVILLE
# Subzone: FERNVALE
# Subzone: FAJAR
# Subzone: HONG KAH NORTH
# Subzone: INTERNATIONAL BUSINESS PARK
# Subzone: NORTHLAND
# Subzone: YUHUA EAST
# Subzone: BUKIT BATOK WEST
# Subzone: RIVERVALE
# Subzone: ANCHORVALE
# Subzone: FRANKEL
# Subzone: KAKI BUKIT
# Subzone: PASIR RIS DRIVE
# Subzone: WOODLANDS EAST
# Subzone: MIDVIEW
# Subzone: SERANGOON CENTRAL
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: LORONG AH SOO
# Subzone: JURONG GATEWAY
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: TAMPINES EAST
# Subzone: SIMEI
# Subzone: SEMBAWANG EAST
# Subzone: TAMPINES NORTH
# Subzone: TAMPINES NORTH
# Subzone: TAMPINES EAST
# Subzone: TAMPINES WEST
# Subzone: TAMPINES EAST
# Subzone: PUNGGOL FIELD
# Subzone: SIMEI
# Subzone: WOODLANDS EAST
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: PASIR RIS DRIVE
# Subzone: YUNNAN
# Subzone: MIDVIEW
# Subzone: CLEMENTI NORTH
# Subzone: EVERTON PARK
# Subzone: LOWER SELETAR
# Subzone: LEONIE HILL
# Subzone: LORONG AH SOO
# Subzone: HONG KAH
# Subzone: SELETAR HILLS
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: JURONG WEST CENTRAL
# Subzone: NORTHSHORE
# Subzone: FRANKEL
# Subzone: XILIN
# Subzone: ISTANA NEGARA
# Subzone: MACPHERSON
# Subzone: SAUJANA
# Subzone: MOULMEIN
# Subzone: BALESTIER
# Subzone: MACPHERSON
# Subzone: HOLLAND ROAD
# Subzone: HONG KAH
# Subzone: WATERWAY EAST
# Subzone: HILLCREST
# Subzone: TELOK BLANGAH RISE
# Subzone: CLEMENTI WOODS
# Subzone: BOON LAY PLACE
# Subzone: BENDEMEER
# Subzone: FRANKEL
# Subzone: BUKIT BATOK EAST
# Subzone: JELEBU
# Subzone: BUKIT BATOK SOUTH
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: KIM KEAT
# Subzone: BENDEMEER
# Subzone: DOVER
# Subzone: KAMPONG TIONG BAHRU
# Subzone: HOLLAND DRIVE
# Subzone: ANCHORVALE
# Subzone: RIVERVALE
# Subzone: RIVERVALE
# Subzone: RIVERVALE
# Subzone: WOODLANDS EAST
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: BUKIT BATOK SOUTH
# Subzone: BEDOK SOUTH
# Subzone: MOULMEIN
# Subzone: DAIRY FARM
# Subzone: TAMPINES EAST
# Subzone: SIGLAP
# Subzone: MARINE PARADE
# Subzone: RIVERVALE
# Subzone: LOWER SELETAR
# Subzone: SENGKANG TOWN CENTRE
# Subzone: KATONG
# Subzone: MATILDA
# Subzone: ULU PANDAN
# Subzone: ROBERTSON QUAY
# Subzone: PASIR PANJANG 2
# Subzone: MACKENZIE
# Subzone: RIVERVALE
# Subzone: YUHUA EAST
# Subzone: YEW TEE
# Subzone: BRICKWORKS
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: TELOK BLANGAH DRIVE
# Subzone: KAMPONG JAVA
# Subzone: SENGKANG TOWN CENTRE
# Subzone: WOODLANDS EAST
# Subzone: WATERWAY EAST
# Subzone: JURONG WEST CENTRAL
# Subzone: PASIR RIS WEST
# Subzone: CITY HALL
# Subzone: SENGKANG TOWN CENTRE
# Subzone: COMPASSVALE
# Subzone: MARGARET DRIVE
# Subzone: CLEMENTI WOODS
# Subzone: PASIR RIS WEST
# Subzone: FRANKEL
# Subzone: KOVAN
# Subzone: HOLLAND ROAD
# Subzone: RIDOUT
# Subzone: JELEBU
# Subzone: WOODGROVE
# Subzone: SEMBAWANG EAST
# Subzone: TOA PAYOH CENTRAL
# Subzone: TAI SENG
# Subzone: TAMPINES WEST
# Subzone: MARINE PARADE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: KIAN TECK
# Subzone: YISHUN SOUTH
# Subzone: CHINATOWN
# Subzone: WOODLANDS SOUTH
# Subzone: TAMPINES WEST
# Subzone: WOODLANDS EAST
# Subzone: TAMPINES EAST
# Subzone: TIONG BAHRU STATION
# Subzone: ADMIRALTY
# Subzone: FRANKEL
# Subzone: SIMEI
# Subzone: TYERSALL
# Subzone: YUNNAN
# Subzone: KANGKAR
# Subzone: WOODLANDS EAST
# Subzone: ANCHORVALE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: MATILDA
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: CHINATOWN
# Subzone: FRANKEL
# Subzone: TECK WHYE
# Subzone: ROBERTSON QUAY
# Subzone: PASIR RIS PARK
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: GEYLANG EAST
# Subzone: BALESTIER
# Subzone: KATONG
# Subzone: ALEXANDRA HILL
# Subzone: TIONG BAHRU
# Subzone: TAGORE
# Subzone: ULU PANDAN
# Subzone: ANAK BUKIT
# Subzone: WATERWAY EAST
# Subzone: UPPER THOMSON
# Subzone: TAMPINES EAST
# Subzone: WOODLANDS EAST
# Subzone: UPPER THOMSON
# Subzone: JURONG GATEWAY
# Subzone: FERNVALE
# Subzone: SEMBAWANG CENTRAL
# Subzone: JURONG WEST CENTRAL
# Subzone: TAMPINES WEST
# Subzone: KEBUN BAHRU
# Subzone: WOODLANDS SOUTH
# Subzone: BUKIT MERAH
# Subzone: KALLANG WAY
# Subzone: SIMEI
# Subzone: UPPER THOMSON
# Subzone: NASSIM
# Subzone: UPPER PAYA LEBAR
# Subzone: KANGKAR
# Subzone: TAI SENG
# Subzone: TRAFALGAR
# Subzone: LORONG AH SOO
# Subzone: HOUGANG WEST
# Subzone: TAMPINES WEST
# Subzone: TAMPINES WEST
# Subzone: TRAFALGAR
# Subzone: TIONG BAHRU
# Subzone: JURONG GATEWAY
# Subzone: ADMIRALTY
# Subzone: NATURE RESERVE
# Subzone: YIO CHU KANG EAST
# Subzone: NORTHLAND
# Subzone: FAJAR
# Subzone: CHINATOWN
# Subzone: HOUGANG WEST
# Subzone: WOODLANDS REGIONAL CENTRE
# Subzone: NASSIM
# Subzone: ANSON
# Subzone: SENGKANG TOWN CENTRE
# Subzone: SENGKANG TOWN CENTRE
# Subzone: ANCHORVALE
# Subzone: FRANKEL
# Subzone: MURAI
# Subzone: ALJUNIED
# Subzone: BOON LAY PLACE
# Subzone: PASIR PANJANG 1
# Subzone: KALLANG BAHRU
# Subzone: SENNETT
# Subzone: POTONG PASIR
# Subzone: ANCHORVALE
# Subzone: TAMAN JURONG
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: KATONG
# Subzone: TAMPINES EAST
# Subzone: MIDVIEW
# Subzone: MALCOLM
# Subzone: TAMPINES WEST
# Subzone: HILLCREST
# Subzone: PENG SIANG
# Subzone: MEI CHIN
# Subzone: ONE NORTH
# Subzone: BENDEMEER
# Subzone: TAMPINES WEST
# Subzone: TOWNSVILLE
# Subzone: COMPASSVALE
# Subzone: BALESTIER
# Subzone: UPPER THOMSON
# Subzone: YISHUN WEST
# Subzone: YISHUN EAST
# Subzone: LEONIE HILL
# Subzone: BOON LAY PLACE
# Subzone: KANGKAR
# Subzone: KEAT HONG
# Subzone: MARGARET DRIVE
# Subzone: RIVERVALE
# Subzone: MACPHERSON
# Subzone: PENG SIANG
# Subzone: BUKIT BATOK SOUTH
# Subzone: KEBUN BAHRU
# Subzone: SERANGOON GARDEN
# Subzone: TAMAN JURONG
# Subzone: YUHUA WEST
# Subzone: BUKIT HO SWEE
# Subzone: DAIRY FARM
# Subzone: MARINA SOUTH
# Subzone: DEPOT ROAD
# Subzone: KATONG
# Subzone: KOVAN
# Subzone: POTONG PASIR
# Subzone: TOA PAYOH CENTRAL
# Subzone: PUNGGOL FIELD
# Subzone: MATILDA
# Subzone: BALESTIER
# Subzone: MOUNTBATTEN
# Subzone: YISHUN EAST
# Subzone: SEMBAWANG CENTRAL
# Subzone: HILLVIEW
# Subzone: PASIR RIS PARK
# Subzone: KEMBANGAN
# Subzone: FRANKEL
# Subzone: YIO CHU KANG EAST
# Subzone: BUKIT BATOK CENTRAL
# Subzone: CLEMENTI CENTRAL
# Subzone: HONG KAH
# Subzone: HONG KAH
# Subzone: LAVENDER
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: SHANGRI-LA
# Subzone: BALESTIER
# Subzone: GEYLANG EAST
# Subzone: ROBERTSON QUAY
# Subzone: SERANGOON GARDEN
# Subzone: WOODGROVE
# Subzone: ADMIRALTY
# Subzone: SEMBAWANG CENTRAL
# Subzone: BISHAN EAST
# Subzone: TECK WHYE
# Subzone: MARYMOUNT
# Subzone: WOODLANDS WEST
# Subzone: YUNNAN
# Subzone: WOODLANDS EAST
# Subzone: SENJA
# Subzone: JURONG WEST CENTRAL
# Subzone: FAJAR
# Subzone: FAJAR
# Subzone: JURONG WEST CENTRAL
# Subzone: YUHUA EAST
# Subzone: TAMAN JURONG
# Subzone: WATERWAY EAST
# Subzone: PUNGGOL FIELD
# Subzone: WATERWAY EAST
# Subzone: PASIR RIS WEST
# Subzone: ONE NORTH
# Subzone: QUEENSWAY
# Subzone: TAMAN JURONG
# Subzone: SERANGOON GARDEN
# Subzone: MOULMEIN
# Subzone: DAIRY FARM
# Subzone: HOUGANG WEST
# Subzone: WATERWAY EAST
# Subzone: MIDVIEW
# Subzone: PASIR RIS DRIVE
# Subzone: COMPASSVALE
# Subzone: JURONG WEST CENTRAL
# Subzone: YEW TEE
# Subzone: VICTORIA
# Subzone: FERNVALE
# Subzone: LORONG 8 TOA PAYOH
# Subzone: MATILDA
# Subzone: PASIR RIS WEST
# Subzone: KAMPONG UBI
# Subzone: SENNETT
# Subzone: ALJUNIED
# Subzone: XILIN
# Subzone: BEDOK NORTH
# Subzone: PASIR PANJANG 1
# Subzone: NASSIM
# Subzone: PUNGGOL FIELD
# Subzone: TAMPINES EAST
# Subzone: CHOA CHU KANG NORTH
# Subzone: CHOA CHU KANG CENTRAL
# Subzone: ALJUNIED
# Subzone: BOON LAY PLACE
# Subzone: HONG KAH
# Subzone: YISHUN EAST
# Subzone: PASIR RIS DRIVE
# Subzone: BUKIT BATOK WEST
# Subzone: PASIR RIS WEST
# Subzone: CLEMENTI NORTH
# Subzone: FERNVALE
# Subzone: NORTHSHORE
# Subzone: WOODLANDS EAST
# Subzone: ANCHORVALE
# Subzone: PUNGGOL TOWN CENTRE
# Subzone: ADMIRALTY
# Subzone: SEMBAWANG NORTH
# Subzone: SENNETT
# Subzone: PUNGGOL FIELD
# Subzone: WATERWAY EAST
# Subzone: SENJA
# Subzone: TAMPINES EAST
# Subzone: FERNVALE
# Subzone: ANCHORVALE
# Subzone: FAJAR
# Subzone: BEDOK NORTH
# Subzone: BENDEMEER
# Subzone: ALEXANDRA NORTH
# Subzone: TAMPINES NORTH
# Subzone: NATURE RESERVE
# Subzone: SEMBAWANG NORTH
# Subzone: WOODLANDS WEST
# Subzone: LORONG CHUAN
# Subzone: WOODLANDS SOUTH
# Subzone: TRAFALGAR
# Subzone: MALCOLM
# Subzone: BALESTIER
# Subzone: HONG KAH
# Subzone: TAMPINES WEST
# Subzone: LORONG AH SOO
# Subzone: KEMBANGAN
# Subzone: ANG MO KIO TOWN CENTRE
# Subzone: BANGKIT
# Subzone: TAMAN JURONG
# Subzone: GUILIN
# Subzone: ALJUNIED
# Subzone: PARK
# Subzone: TAMPINES WEST
# Subzone: TAI SENG
# Subzone: TANGLIN HALT
# Subzone: BIDADARI
# Subzone: NORTHSHORE
# Subzone: BOON KENG
# Subzone: YIO CHU KANG WEST
# Subzone: WOODLANDS EAST
# Subzone: KANGKAR
# Subzone: PASIR RIS DRIVE
# Subzone: PENG SIANG
# Subzone: UPPER THOMSON
# Subzone: FERNVALE
# Subzone: SEMBAWANG EAST
# Subzone: WOODLANDS SOUTH
# Subzone: SEMBAWANG CENTRAL
# Subzone: TRAFALGAR

# %%
# save result
df.to_csv('./data_processed/postcode_ll_subzone.csv', index=False)
